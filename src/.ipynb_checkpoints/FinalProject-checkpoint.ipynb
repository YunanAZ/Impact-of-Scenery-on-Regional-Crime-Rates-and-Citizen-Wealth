# %% [markdown]
# # COGS 108 - Final Project

# %% [markdown]
# # Overview

# %% [markdown]
# # Names
#
# # Group Members IDs
#
# # Research Question
#
# # Background and Prior Work

# %% [markdown]
# # Hypothesis

# %% [markdown]
# # Dataset(s)

# %% [markdown]
# # Setup

# %%
import pandas as pd
import numpy as np
import matplotlib as plt

# %% [markdown]
# # Data Cleaning

# %%
#read the pfac data, which shows the actuall police control area of the county
pfac = pd.read_csv('../data/PFAC.csv')

#read the scenery data 
df = pd.read_csv('scenery.csv', encoding = "ISO-8859-1")
print('Size of the dataset: ' + str(df.shape[0]))

#switch the colomns and rows for pfac data
pfac = pfac.transpose()
pfac.reset_index(inplace = True)

#reset the header of the pfac data
new_header = pfac.iloc[0]
pfac = pfac[1:]
pfac.columns = new_header
crime_df = pd.read_csv('../data/number_crime.csv')

print(pfac.shape[1])
# Out:
# Size of the dataset: 212155
# 43

# %%
#find the county
def matchCounty(area):
    for i in pfac.columns:
        if area in list(pfac[i]):
            return i
    return np.nan

# %%
#the unique
len(df['County'].unique())
# Out:
# 214

# %%
#df['County'].unique()

# %%
df['County'] = df['County'].apply(matchCounty)
len(df['County'].unique())
# Out:
# 44

# %%
sum(df['County'].isnull())
# Out:
# 65530

# %% [markdown]
# # Data Analysis & Results

# %% [markdown]
# ##### comment
# drop every column except 'County' and 'Rating'
#
# calculate avg_rating and standard_deviation from 'Rating' and add 'num_pictures'

# %%
import statistics

df_rate = df.drop(columns=['ID', 'Place', 'Variance', 'Near', 'Category', 'Image', 'Date', 'URL'])
df_rate = df_rate.dropna()
df_rate['Avg_Rating'] = df_rate['Rating']
df_rate['Standard_Deviation'] = df_rate['Rating']
df_rate = df_rate.drop(columns=['Rating'])
df_rate['num_pictures'] = 1


aggregation_functions = {'Avg_Rating': 'mean', 'Standard_Deviation': 'std', 'num_pictures': 'sum'}
df_rate_mean = df_rate.groupby(df_rate['County']).aggregate(aggregation_functions)
df_rate_mean
# Out:
#                      Avg_Rating  Standard_Deviation  num_pictures
# County
# Avon and Somerset      2.712359            1.873534          4755
# Bedfordshire           2.548122            1.870577          1187
# Cambridgeshire         2.462462            1.848670          3209
# Cheshire               2.526800            1.835459          2296
# City of London         3.209225            1.974855             4
# Cleveland              2.363048            1.900951           299
# Cumbria                2.908924            1.928069          6869
# Derbyshire             2.706742            1.929414          2558
# Devon and Cornwall     2.788292            1.834246         10616
# Dorset                 2.678697            1.826376          2707
# Durham                 2.698612            1.863479          2367
# Dyfed-Powys            2.876897            1.834040          6096
# Essex                  2.471854            1.831060          3708
# Gloucestershire        2.714484            1.846298          2642
# Greater Manchester     2.428156            2.068918          1192
# Gwent                  2.581222            1.935530           591
# Hampshire              2.600870            1.840056          4187
# Hertfordshire          2.451411            1.895379          1648
# Humberside             2.557852            1.787980          3532
# Kent                   2.503552            1.787717          3851
# Lancashire             2.600273            1.893096          3016
# Leicestershire         2.519469            1.785538          2449
# Lincolnshire           2.534675            1.809087          5732
# Merseyside             2.445716            2.039121           681
# Metropolitan Police    1.938014            1.907292          1284
# Norfolk                2.633350            1.841184          5314
# North Wales            2.941677            1.979406          6228
# North Yorkshire        2.771272            1.866603          8073
# Northamptonshire       2.575889            1.846145          2272
# Northumbria            2.821843            1.893762          5257
# Nottinghamshire        2.464685            1.880608          2087
# South Wales            2.692996            1.855747          6290
# South Yorkshire        2.287032            1.763057          1431
# Staffordshire          2.560061            1.869428          2608
# Suffolk                2.623217            1.822361          3796
# Surrey                 2.633970            1.971105          1624
# Sussex                 2.723256            1.860760          3694
# Thames Valley          2.566494            1.820355          5558
# Warwickshire           2.517741            1.825380          1873
# West Mercia            2.654227            1.812546          4838
# West Midlands          2.468773            1.809740          2968
# West Yorkshire         2.538564            1.946999          1921
# Wiltshire              2.692212            1.848735          3317

# %%
plot1 = df_rate_mean['Avg_Rating'].plot(figsize=(15, 5),kind='bar')
print(plot1)
# Out:
# AxesSubplot(0.125,0.11;0.775x0.77)

# %%
import patsy
import statsmodels.api as sm
import scipy.stats as stats
from scipy.stats import ttest_ind, chisquare, normaltest

# %%
df_crime = pd.read_csv('../data/crime_final.csv')
df_crime.drop(df_crime.columns[0],axis=1,inplace = True)
t = df_rate_mean['Avg_Rating']
df_crime['avg_scenery'] = t

l = df_rate_mean.index.tolist()
for i in range(0,41):
   
    if df_crime.loc[i]['AreaName'] in l:     
        df_crime.set_value(i,'avg_scenery', df_rate_mean.loc[df_crime.loc[i]['AreaName']]['Avg_Rating'])
# Out:
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/ipykernel_launcher.py:10: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
#   # Remove the CWD from sys.path while we load stuff.

# %%
df_crime = df_crime.dropna()
#print(df_crime)
for i in range(0,41):
     for j in df_crime.columns:
        if ',' in str(df_crime.loc[i][j]):
             df_crime.set_value(i, j, df_crime.loc[i][j].replace(',' , ''))

for i in df_crime.columns:
     if i != 'AreaName':
        df_crime[i] = df_crime[i].astype(float)
# Out:
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/ipykernel_launcher.py:6: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead

# %%
df_crime.corr()
# Out:
#                              PopulationFigures  HouseHoldfigures  \
# PopulationFigures                     1.000000          1.000000
# HouseHoldfigures                      1.000000          1.000000
# TotalRecordedCrime                    0.979003          0.979003
# ViolenceAgainstThePerson              0.947849          0.947849
# Homicide                              0.934166          0.934166
# ViolenceWithInjury                    0.975963          0.975963
# ViolenceWithoutInjury                 0.931700          0.931700
# StalkingAndHarassment                 0.869531          0.869531
# UnlawfulDriving                       0.551543          0.551543
# SexualOffences                        0.966215          0.966215
# Robbery                               0.954149          0.954149
# TheftOffences                         0.984341          0.984341
# Burglary                              0.969707          0.969707
# ResidentialBurglary                   0.965303          0.965303
# Non-residentialBurglary               0.974654          0.974654
# VehicleOffences                       0.977001          0.977001
# TheftFromThePerson                    0.936980          0.936980
# BicycleTheft                          0.945249          0.945249
# Shoplifting                           0.955417          0.955417
# OtherTheftOffences                    0.983866          0.983866
# CriminalDamageAndArson                0.911662          0.911662
# DrugOffences                          0.950659          0.950659
# PossessionOfWeaponsOffences           0.967467          0.967467
# PublicOrderOffences                   0.794613          0.794613
# MiscellaneousCrimes                   0.824233          0.824233
# avg_scenery                          -0.627361         -0.627361
#
#                              TotalRecordedCrime  ViolenceAgainstThePerson  \
# PopulationFigures                      0.979003                  0.947849
# HouseHoldfigures                       0.979003                  0.947849
# TotalRecordedCrime                     1.000000                  0.983728
# ViolenceAgainstThePerson               0.983728                  1.000000
# Homicide                               0.958381                  0.927108
# ViolenceWithInjury                     0.986558                  0.981207
# ViolenceWithoutInjury                  0.971041                  0.991228
# StalkingAndHarassment                  0.932152                  0.970730
# UnlawfulDriving                        0.580510                  0.651049
# SexualOffences                         0.986160                  0.990481
# Robbery                                0.948262                  0.884223
# TheftOffences                          0.986053                  0.943408
# Burglary                               0.986927                  0.954925
# ResidentialBurglary                    0.983721                  0.949417
# Non-residentialBurglary                0.988249                  0.963208
# VehicleOffences                        0.974121                  0.925454
# TheftFromThePerson                     0.926005                  0.857120
# BicycleTheft                           0.914732                  0.850742
# Shoplifting                            0.971947                  0.962799
# OtherTheftOffences                     0.982871                  0.940721
# CriminalDamageAndArson                 0.957027                  0.978496
# DrugOffences                           0.928562                  0.873337
# PossessionOfWeaponsOffences            0.977550                  0.954285
# PublicOrderOffences                    0.876080                  0.905671
# MiscellaneousCrimes                    0.900986                  0.942395
# avg_scenery                           -0.644121                 -0.624625
#
#                              Homicide  ViolenceWithInjury  \
# PopulationFigures            0.934166            0.975963
# HouseHoldfigures             0.934166            0.975963
# TotalRecordedCrime           0.958381            0.986558
# ViolenceAgainstThePerson     0.927108            0.981207
# Homicide                     1.000000            0.943170
# ViolenceWithInjury           0.943170            1.000000
# ViolenceWithoutInjury        0.917295            0.959191
# StalkingAndHarassment        0.856292            0.923183
# UnlawfulDriving              0.486557            0.585113
# SexualOffences               0.938992            0.985241
# Robbery                      0.937175            0.926979
# TheftOffences                0.951667            0.969251
# Burglary                     0.963538            0.974853
# ResidentialBurglary          0.961285            0.969482
# Non-residentialBurglary      0.962276            0.982575
# VehicleOffences              0.948085            0.959314
# TheftFromThePerson           0.900400            0.894263
# BicycleTheft                 0.870170            0.887373
# Shoplifting                  0.914771            0.970907
# OtherTheftOffences           0.941413            0.962451
# CriminalDamageAndArson       0.907548            0.953062
# DrugOffences                 0.880625            0.910299
# PossessionOfWeaponsOffences  0.955795            0.961521
# PublicOrderOffences          0.852906            0.845559
# MiscellaneousCrimes          0.859337            0.883669
# avg_scenery                 -0.628520           -0.627876
#
#                              ViolenceWithoutInjury  StalkingAndHarassment  \
# PopulationFigures                         0.931700               0.869531
# HouseHoldfigures                          0.931700               0.869531
# TotalRecordedCrime                        0.971041               0.932152
# ViolenceAgainstThePerson                  0.991228               0.970730
# Homicide                                  0.917295               0.856292
# ViolenceWithInjury                        0.959191               0.923183
# ViolenceWithoutInjury                     1.000000               0.951850
# StalkingAndHarassment                     0.951850               1.000000
# UnlawfulDriving                           0.665165               0.672745
# SexualOffences                            0.985448               0.936919
# Robbery                                   0.861113               0.801602
# TheftOffences                             0.924105               0.873768
# Burglary                                  0.933709               0.895792
# ResidentialBurglary                       0.928181               0.890509
# Non-residentialBurglary                   0.942223               0.903902
# VehicleOffences                           0.904148               0.849268
# TheftFromThePerson                        0.837164               0.779008
# BicycleTheft                              0.844699               0.750799
# Shoplifting                               0.944062               0.915365
# OtherTheftOffences                        0.923723               0.873175
# CriminalDamageAndArson                    0.972040               0.956036
# DrugOffences                              0.850641               0.798884
# PossessionOfWeaponsOffences               0.945937               0.891392
# PublicOrderOffences                       0.921920               0.898710
# MiscellaneousCrimes                       0.950773               0.943874
# avg_scenery                              -0.602443              -0.613138
#
#                              UnlawfulDriving  SexualOffences  ...  \
# PopulationFigures                   0.551543        0.966215  ...
# HouseHoldfigures                    0.551543        0.966215  ...
# TotalRecordedCrime                  0.580510        0.986160  ...
# ViolenceAgainstThePerson            0.651049        0.990481  ...
# Homicide                            0.486557        0.938992  ...
# ViolenceWithInjury                  0.585113        0.985241  ...
# ViolenceWithoutInjury               0.665165        0.985448  ...
# StalkingAndHarassment               0.672745        0.936919  ...
# UnlawfulDriving                     1.000000        0.636161  ...
# SexualOffences                      0.636161        1.000000  ...
# Robbery                             0.420159        0.901442  ...
# TheftOffences                       0.507270        0.954813  ...
# Burglary                            0.529121        0.957988  ...
# ResidentialBurglary                 0.523222        0.951100  ...
# Non-residentialBurglary             0.541998        0.970261  ...
# VehicleOffences                     0.490823        0.936800  ...
# TheftFromThePerson                  0.379916        0.874309  ...
# BicycleTheft                        0.406655        0.879304  ...
# Shoplifting                         0.616027        0.969153  ...
# OtherTheftOffences                  0.500177        0.954709  ...
# CriminalDamageAndArson              0.660493        0.971494  ...
# DrugOffences                        0.436328        0.883265  ...
# PossessionOfWeaponsOffences         0.585959        0.964303  ...
# PublicOrderOffences                 0.589126        0.892117  ...
# MiscellaneousCrimes                 0.706928        0.924248  ...
# avg_scenery                        -0.380264       -0.608754  ...
#
#                              TheftFromThePerson  BicycleTheft  Shoplifting  \
# PopulationFigures                      0.936980      0.945249     0.955417
# HouseHoldfigures                       0.936980      0.945249     0.955417
# TotalRecordedCrime                     0.926005      0.914732     0.971947
# ViolenceAgainstThePerson               0.857120      0.850742     0.962799
# Homicide                               0.900400      0.870170     0.914771
# ViolenceWithInjury                     0.894263      0.887373     0.970907
# ViolenceWithoutInjury                  0.837164      0.844699     0.944062
# StalkingAndHarassment                  0.779008      0.750799     0.915365
# UnlawfulDriving                        0.379916      0.406655     0.616027
# SexualOffences                         0.874309      0.879304     0.969153
# Robbery                                0.983297      0.939420     0.893320
# TheftOffences                          0.965911      0.950965     0.954117
# Burglary                               0.933293      0.910760     0.955427
# ResidentialBurglary                    0.934051      0.908606     0.951300
# Non-residentialBurglary                0.923516      0.909641     0.959687
# VehicleOffences                        0.960015      0.940850     0.937735
# TheftFromThePerson                     1.000000      0.952064     0.860921
# BicycleTheft                           0.952064      1.000000     0.885504
# Shoplifting                            0.860921      0.885504     1.000000
# OtherTheftOffences                     0.974425      0.955804     0.944483
# CriminalDamageAndArson                 0.786077      0.798933     0.959025
# DrugOffences                           0.976502      0.942438     0.878637
# PossessionOfWeaponsOffences            0.904503      0.896424     0.948776
# PublicOrderOffences                    0.696786      0.693155     0.846554
# MiscellaneousCrimes                    0.705277      0.700474     0.892489
# avg_scenery                           -0.588403     -0.611204    -0.662492
#
#                              OtherTheftOffences  CriminalDamageAndArson  \
# PopulationFigures                      0.983866                0.911662
# HouseHoldfigures                       0.983866                0.911662
# TotalRecordedCrime                     0.982871                0.957027
# ViolenceAgainstThePerson               0.940721                0.978496
# Homicide                               0.941413                0.907548
# ViolenceWithInjury                     0.962451                0.953062
# ViolenceWithoutInjury                  0.923723                0.972040
# StalkingAndHarassment                  0.873175                0.956036
# UnlawfulDriving                        0.500177                0.660493
# SexualOffences                         0.954709                0.971494
# Robbery                                0.978857                0.825048
# TheftOffences                          0.995771                0.902901
# Burglary                               0.977376                0.924764
# ResidentialBurglary                    0.974885                0.917563
# Non-residentialBurglary                0.976698                0.938219
# VehicleOffences                        0.985432                0.881409
# TheftFromThePerson                     0.974425                0.786077
# BicycleTheft                           0.955804                0.798933
# Shoplifting                            0.944483                0.959025
# OtherTheftOffences                     1.000000                0.896845
# CriminalDamageAndArson                 0.896845                1.000000
# DrugOffences                           0.965893                0.806957
# PossessionOfWeaponsOffences            0.960063                0.934018
# PublicOrderOffences                    0.798032                0.932319
# MiscellaneousCrimes                    0.820604                0.964710
# avg_scenery                           -0.623931               -0.613458
#
#                              DrugOffences  PossessionOfWeaponsOffences  \
# PopulationFigures                0.950659                     0.967467
# HouseHoldfigures                 0.950659                     0.967467
# TotalRecordedCrime               0.928562                     0.977550
# ViolenceAgainstThePerson         0.873337                     0.954285
# Homicide                         0.880625                     0.955795
# ViolenceWithInjury               0.910299                     0.961521
# ViolenceWithoutInjury            0.850641                     0.945937
# StalkingAndHarassment            0.798884                     0.891392
# UnlawfulDriving                  0.436328                     0.585959
# SexualOffences                   0.883265                     0.964303
# Robbery                          0.958539                     0.931394
# TheftOffences                    0.957918                     0.966686
# Burglary                         0.924284                     0.968370
# ResidentialBurglary              0.924903                     0.964912
# Non-residentialBurglary          0.914982                     0.970576
# VehicleOffences                  0.949455                     0.960717
# TheftFromThePerson               0.976502                     0.904503
# BicycleTheft                     0.942438                     0.896424
# Shoplifting                      0.878637                     0.948776
# OtherTheftOffences               0.965893                     0.960063
# CriminalDamageAndArson           0.806957                     0.934018
# DrugOffences                     1.000000                     0.905630
# PossessionOfWeaponsOffences      0.905630                     1.000000
# PublicOrderOffences              0.697458                     0.857994
# MiscellaneousCrimes              0.717624                     0.888947
# avg_scenery                     -0.597085                    -0.632690
#
#                              PublicOrderOffences  MiscellaneousCrimes  \
# PopulationFigures                       0.794613             0.824233
# HouseHoldfigures                        0.794613             0.824233
# TotalRecordedCrime                      0.876080             0.900986
# ViolenceAgainstThePerson                0.905671             0.942395
# Homicide                                0.852906             0.859337
# ViolenceWithInjury                      0.845559             0.883669
# ViolenceWithoutInjury                   0.921920             0.950773
# StalkingAndHarassment                   0.898710             0.943874
# UnlawfulDriving                         0.589126             0.706928
# SexualOffences                          0.892117             0.924248
# Robbery                                 0.728218             0.741542
# TheftOffences                           0.797717             0.827006
# Burglary                                0.824321             0.861428
# ResidentialBurglary                     0.819521             0.856226
# Non-residentialBurglary                 0.831600             0.869577
# VehicleOffences                         0.769470             0.802718
# TheftFromThePerson                      0.696786             0.705277
# BicycleTheft                            0.693155             0.700474
# Shoplifting                             0.846554             0.892489
# OtherTheftOffences                      0.798032             0.820604
# CriminalDamageAndArson                  0.932319             0.964710
# DrugOffences                            0.697458             0.717624
# PossessionOfWeaponsOffences             0.857994             0.888947
# PublicOrderOffences                     1.000000             0.939488
# MiscellaneousCrimes                     0.939488             1.000000
# avg_scenery                            -0.519384            -0.601004
#
#                              avg_scenery
# PopulationFigures              -0.627361
# HouseHoldfigures               -0.627361
# TotalRecordedCrime             -0.644121
# ViolenceAgainstThePerson       -0.624625
# Homicide                       -0.628520
# ViolenceWithInjury             -0.627876
# ViolenceWithoutInjury          -0.602443
# StalkingAndHarassment          -0.613138
# UnlawfulDriving                -0.380264
# SexualOffences                 -0.608754
# Robbery                        -0.611832
# TheftOffences                  -0.648730
# Burglary                       -0.661576
# ResidentialBurglary            -0.667278
# Non-residentialBurglary        -0.639611
# VehicleOffences                -0.651011
# TheftFromThePerson             -0.588403
# BicycleTheft                   -0.611204
# Shoplifting                    -0.662492
# OtherTheftOffences             -0.623931
# CriminalDamageAndArson         -0.613458
# DrugOffences                   -0.597085
# PossessionOfWeaponsOffences    -0.632690
# PublicOrderOffences            -0.519384
# MiscellaneousCrimes            -0.601004
# avg_scenery                     1.000000
#
# [26 rows x 26 columns]

# %%
outcome_1, predictors_1 = patsy.dmatrices("TotalRecordedCrime ~ avg_scenery", data = df_crime )
mod_1 = sm.OLS(outcome_1, predictors_1)
res_1 = mod_1.fit()
print(res_1.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:     TotalRecordedCrime   R-squared:                       0.415
# Model:                            OLS   Adj. R-squared:                  0.400
# Method:                 Least Squares   F-statistic:                     27.65
# Date:                Sun, 02 Jun 2019   Prob (F-statistic):           5.52e-06
# Time:                        19:44:17   Log-Likelihood:                -530.89
# No. Observations:                  41   AIC:                             1066.
# Df Residuals:                      39   BIC:                             1069.
# Df Model:                           1
# Covariance Type:            nonrobust
# ===============================================================================
#                   coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------
# Intercept    1.273e+06    2.2e+05      5.790      0.000    8.28e+05    1.72e+06
# avg_scenery -4.445e+05   8.45e+04     -5.259      0.000   -6.15e+05   -2.74e+05
# ==============================================================================
# Omnibus:                       29.053   Durbin-Watson:                   1.414
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               67.238
# Skew:                           1.799   Prob(JB):                     2.51e-15
# Kurtosis:                       8.139   Cond. No.                         40.3
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %% [markdown]
# # Ethics & Privacy

# %% [markdown]
# # Conclusion & Discussion
